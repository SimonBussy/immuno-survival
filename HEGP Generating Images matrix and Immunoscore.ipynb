# %% [markdown]
# # Generating Images Matirx and IS

# %%
"""
Generates A dictionary with key=Patient_ID and values = an other dictionnary whose keys are: 
        name of the matrix and values are the number associated to each tile according to their coordinates.
Each matrix are saved in a csvfile accessible for possible vectorization and visualization.

 Need requirements.txt
 pip install -r requirements.txt
 The path are set in the script, if needed change the line in the script
 To acces the matrix after running the script with: python IS_StageMDT_Generating_images_matrix.py
 import IS_StageMDT_Generating_images_matrix
 IS_StageMDT_Generating_images_matrix.load_patients("cache/cd3")
"""

import os
import glob
import math
from collections import defaultdict


import numpy
import pandas
import PIL.Image

# A tile is 78 pixel wide but the delimitation of the tile is 2 pixel thick
# therefore 78.5 was chosen as the pixel size of a tile
TILESIZE = 78.5

#Currently the image are in Densitymap_new, to change when needed
IMGPATH = os.path.join('..', 'HEGP', 'Densitymap_new')
IMGPATH_CD8 = os.path.join(IMGPATH, "cd8")
IMGPATH_CD3 = os.path.join(IMGPATH, "cd3")
DATA_CD3 = "../HEGP/CD3 Tile statistics final"
DATA_CD8 = "../HEGP/CD8 Tile statistics final"

# Also the patient file have all already been rename
# when needed, change the name of the file to OfficialID.anapathID

### DATA GENERATION ##########

# for tumor and invasive front 0 means no and 1 means yes
# if invasivesice Front is a no then the number of cells in the invasive Front is a NaN
# and not a 0
# if all values in the matrix are NaN then that means the tiles don't exist or were rejected

def get_tile_dimensions(image):
 h = int(math.ceil(image.height / TILESIZE))
 w = int(math.ceil(image.width / TILESIZE))
 return h, w


def get_patient_name(filename):
 return os.path.basename(filename)[:6]


def get_patients_matrices(img_path, data_path):

 patients = {}

 for filename in glob.iglob(os.path.join(img_path, '*.jpg')):

     # Extract image and get dimensions (in tile units)
     img = PIL.Image.open(filename)
     img_height, img_width = get_tile_dimensions(img)

     # Extract patient ID
     patient_id = get_patient_name(filename)
     print(patient_id, "({}x{} tiles)".format(img_height, img_width))

     # Extract data frame from CSV data file
     data_filename = next(glob.iglob(os.path.join(data_path, "{}.*".format(patient_id))))
     data = pandas.read_csv(data_filename, sep=';')

     # Get a custom tile id to coordinates mapper for the current file
     def coordinates_from_tile_id(tile_id):
         x = tile_id // img_width
         y = tile_id % img_width
         return x, y


     # Create a default dict
     patients[patient_id] = patient_dict = defaultdict(
         lambda: numpy.full((img_height, img_width), numpy.nan)
     )

     # Iterate on the rows of the data frame
     for index, row in data.iterrows():

         # Get the tile coordinates
         tile_id = int(row['Tile Name'][4:])
         x, y = coordinates_from_tile_id(tile_id)

         # print(tile_id, (x, y), end="\r")
         #Data assignation if no data assigned then nan by default
         #Tiles can be both tumor and IM, one rejected does not mean the other is automatically
         try:
             float(row['Number_Cells_All']) #both IM and CT rejected
         except (TypeError, ValueError):
             print('Both Tile {} rejected\n'.format(tile_id))
             continue

         if row['Tumor_present'] == 'yes':
             patient_dict['Tumor_present'][x, y] = 1
             # check for tile rejection
             assignT=False
             try:
                 float(row['Number_Cells_Tumor'])
                 float(row['Ratio_Cells_per_Tumor'])
                 assignT=True
             except (TypeError, ValueError):
                 print(assignT,'T Tile {} rejected\n'.format(tile_id))

             if assignT:
                 patient_dict['Number_Cells_Tumor'][x, y] = row['Number_Cells_Tumor']
                 patient_dict['Ratio_Cells_per_All_Area'][x, y]=row['Ratio_Cells_per_All_Area']
                 patient_dict['Ratio_Cells_per_Tumor'][x, y]=row['Ratio_Cells_per_Tumor']
                 patient_dict['Area_Tumor_um2'][x, y] = row['Area_Tumor_um2']
                 patient_dict['Area_Cells_Tumor_um2'][x, y] = row['Area_Cells_Tumor_um2']
                 patient_dict['Density_Tumor_images'][x, y]=patient_dict['Ratio_Cells_per_Tumor'][x, y]*patient_dict['Area_Tumor_um2'][x, y]/512251.79746
         else:
             patient_dict['Tumor_present'][x, y] =0
         if row['IM_present'] == 'yes':
             patient_dict['IM_present'][x, y] = 1
             # check for tile rejection
             assignIM=False
             try:
                 float(row['Number_Cells_InvasiveFront'])
                 float(row['Ratio_Cells_per_InvasiveFront'])
                 assignIM=True
             except (TypeError, ValueError): # values for IM exists and are accepted
                 print(assignIM,'IM Tile {} rejected\n'.format(tile_id))
             if assignIM:
                 patient_dict['Number_Cells_InvasiveFront'][x, y] = row['Number_Cells_InvasiveFront']
                 patient_dict['Ratio_Cells_per_All_Area'][x, y]=row['Ratio_Cells_per_All_Area']
                 patient_dict['Ratio_Cells_per_InvasiveFront'][x, y]=row['Ratio_Cells_per_InvasiveFront']
                 patient_dict['Area_IvasiveFront_um2'][x, y] = row['Area_IvasiveFront_um2']
                 patient_dict['Area_Cells_IvasiveFront_um2'][x, y] = row['Area_Cells_IvasiveFront_um2']
                 patient_dict['Density_InvasiveFront_images'][x, y]=patient_dict['Ratio_Cells_per_InvasiveFront'][x, y]*patient_dict['Area_IvasiveFront_um2'][x, y]/512251.79746


         else:
             patient_dict['IM_present'][x, y] = 0

         if patient_dict['Tumor_present'][x, y] == 1 and not patient_dict['Number_Cells_Tumor'][x, y]: #tile rejected even if tumor was identified
             patient_dict['Tumor_present'][x, y] = numpy.nan
         if patient_dict['IM_present'][x, y] ==1 and not patient_dict['Number_Cells_InvasiveFront'][x, y]:#tile rejected even if front was identified
             patient_dict['IM_present'][x, y] = numpy.nan

         if patient_dict['Number_Cells_Tumor'][x, y] or patient_dict['Number_Cells_InvasiveFront'][x, y]: # a tile exists
             patient_dict['Area_All_um2'][x, y] = row['Area_All_um2']
             patient_dict['Area_Cells_All_um2'][x, y] = row['Area_Cells_All_um2']
             patient_dict['Surface_of_stained_cells_um2'][x, y] = row['Surface_of_stained_cells_um2']


 return patients

#### DATA SERIALIZATION

def save_patients(patients, cachedir):
 if not os.path.exists(cachedir):
     os.makedirs(cachedir)
 for patient_id, patient in patients.items():
     if not os.path.exists(os.path.join(cachedir, patient_id)):
         os.mkdir(os.path.join(cachedir, patient_id))
     for arg, matrix in patient.items():
         numpy.savetxt(os.path.join(cachedir, patient_id, arg), matrix)



def load_patients(cachedir):
 patients = {}
 for patient_id in os.listdir(cachedir):
     patients[patient_id] = {}
     for arg in os.listdir(os.path.join(cachedir, patient_id)):
         patients[patient_id][arg] = numpy.genfromtxt(os.path.join(cachedir, patient_id, arg))
 return patients



if __name__ == "__main__":

 PATIENTS_CD3 = get_patients_matrices(IMGPATH_CD3, DATA_CD3)
 PATIENTS_CD8 = get_patients_matrices(IMGPATH_CD8, DATA_CD8)
    
## Check for unnecessary ditionary due to either CD3 images or CD8 images missing
# Since the dictionnary are generated only if the images exist in the folder, checking for existing csv data is irrelevant
for patient_id in list(PATIENTS_CD3.keys()):
    if patient_id not in PATIENTS_CD8:
        PATIENTS_CD3.pop(patient_id)
for patient_id in list(PATIENTS_CD8.keys()):
    if patient_id not in PATIENTS_CD3:
        PATIENTS_CD8.pop(patient_id)


save_patients(PATIENTS_CD3, os.path.join('../Data_output',"cache_HEGP", "cd3"))

save_patients(PATIENTS_CD8, os.path.join('../Data_output',"cache_HEGP", "cd8"))
# Out:
# PAR170 (21x26 tiles)
# PAR171 (23x24 tiles)
# PAR172 (16x35 tiles)
# PAR173 (14x25 tiles)
# PAR174 (10x25 tiles)
# PAR175 (19x23 tiles)
# PAR176 (24x20 tiles)
# PAR177 (20x25 tiles)
# PAR178 (10x8 tiles)
# PAR179 (19x29 tiles)
# PAR180 (20x35 tiles)
# PAR181 (18x9 tiles)
# PAR182 (18x24 tiles)
# PAR183 (17x11 tiles)
# PAR184 (12x28 tiles)
# PAR185 (17x30 tiles)
# PAR186 (22x35 tiles)
# PAR187 (22x38 tiles)
# PAR188 (16x29 tiles)
# PAR189 (14x25 tiles)
# PAR190 (15x15 tiles)
# PAR191 (28x34 tiles)
# Both Tile 323 rejected
#
# Both Tile 324 rejected
#
# Both Tile 358 rejected
#
# Both Tile 359 rejected
#
# PAR192 (9x16 tiles)
# PAR193 (31x39 tiles)
# PAR194 (20x32 tiles)
# PAR195 (30x31 tiles)
# PAR196 (20x30 tiles)
# PAR197 (17x31 tiles)
# PAR198 (29x19 tiles)
# PAR199 (22x41 tiles)
# PAR200 (11x18 tiles)
# PAR201 (24x23 tiles)
# PAR202 (17x35 tiles)
# PAR203 (28x14 tiles)
# PAR204 (16x32 tiles)
# PAR205 (27x34 tiles)
# PAR206 (18x32 tiles)
# PAR207 (23x17 tiles)
# PAR208 (26x29 tiles)
# PAR209 (17x24 tiles)
# PAR210 (18x16 tiles)
# PAR211 (25x25 tiles)
# PAR212 (17x31 tiles)
# PAR213 (17x28 tiles)
# PAR214 (16x18 tiles)
# PAR215 (13x24 tiles)
# PAR216 (24x17 tiles)
# PAR217 (11x18 tiles)
# PAR218 (13x22 tiles)
# PAR219 (14x23 tiles)
# PAR220 (21x38 tiles)
# PAR221 (23x27 tiles)
# PAR223 (10x12 tiles)
# PAR224 (16x26 tiles)
# PAR225 (21x28 tiles)
# PAR226 (21x19 tiles)
# PAR227 (19x21 tiles)
# PAR229 (12x33 tiles)
# PAR230 (19x20 tiles)
# PAR231 (30x19 tiles)
# PAR232 (17x16 tiles)
# PAR233 (18x35 tiles)
# PAR234 (19x16 tiles)
# PAR235 (5x5 tiles)
# PAR236 (20x24 tiles)
# PAR237 (18x33 tiles)
# PAR238 (16x22 tiles)
# PAR239 (23x22 tiles)
# PAR240 (20x31 tiles)
# PAR241 (18x33 tiles)
# PAR242 (13x15 tiles)
# PAR243 (19x16 tiles)
# PAR244 (28x32 tiles)
# PAR245 (24x27 tiles)
# PAR246 (12x26 tiles)
# PAR247 (26x28 tiles)
# PAR249 (19x27 tiles)
# PAR250 (19x28 tiles)
# PAR251 (18x25 tiles)
# PAR252 (10x15 tiles)
# PAR253 (21x17 tiles)
# PAR254 (24x30 tiles)
# PAR255 (14x28 tiles)
# PAR256 (18x22 tiles)
# PAR257 (10x30 tiles)
# PAR258 (21x27 tiles)
# PAR259 (14x19 tiles)
# PAR260 (18x22 tiles)
# PAR261 (13x30 tiles)
# PAR262 (23x31 tiles)
# PAR263 (23x30 tiles)
# PAR264 (14x29 tiles)
# PAR265 (21x26 tiles)
# PAR266 (18x18 tiles)
# PAR267 (22x37 tiles)
# PAR268 (15x33 tiles)
# PAR269 (22x34 tiles)
# PAR270 (11x33 tiles)
# PAR271 (14x21 tiles)
# PAR272 (29x31 tiles)
# PAR273 (14x26 tiles)
# PAR274 (24x35 tiles)
# PAR275 (25x21 tiles)
# PAR276 (27x26 tiles)
# PAR277 (14x21 tiles)
# PAR278 (12x26 tiles)
# PAR279 (15x34 tiles)
# PAR280 (25x29 tiles)
# PAR281 (21x13 tiles)
# PAR282 (17x18 tiles)
# PAR283 (18x29 tiles)
# PAR284 (20x32 tiles)
# PAR285 (25x17 tiles)
# PAR286 (16x24 tiles)
# PAR287 (21x14 tiles)
# PAR288 (16x30 tiles)
# PAR289 (24x29 tiles)
# PAR290 (11x17 tiles)
# PAR291 (26x27 tiles)
# PAR292 (14x25 tiles)
# PAR293 (13x26 tiles)
# PAR294 (15x19 tiles)
# PAR295 (19x11 tiles)
# PAR296 (20x26 tiles)
# PAR297 (26x25 tiles)
# PAR298 (22x16 tiles)
# PAR299 (21x37 tiles)
# PAR300 (10x6 tiles)
# PAR301 (29x25 tiles)
# PAR302 (20x32 tiles)
# PAR303 (19x25 tiles)
# PAR304 (14x33 tiles)
# PAR305 (28x33 tiles)
# PAR306 (28x29 tiles)
# PAR307 (29x50 tiles)
# PAR308 (12x32 tiles)
# PAR309 (25x26 tiles)
# PAR310 (27x26 tiles)
# PAR311 (25x30 tiles)
# PAR312 (27x18 tiles)
# PAR313 (21x31 tiles)
# PAR314 (26x28 tiles)
# PAR315 (17x31 tiles)
# PAR316 (16x28 tiles)
# PAR317 (27x21 tiles)
# PAR318 (18x22 tiles)
# PAR319 (28x35 tiles)
# PAR320 (23x31 tiles)
# PAR321 (26x31 tiles)
# PAR322 (14x30 tiles)
# PAR323 (24x37 tiles)
# PAR324 (17x19 tiles)
# PAR325 (12x27 tiles)
# PAR326 (14x24 tiles)
# PAR327 (24x40 tiles)
# PAR328 (24x19 tiles)
# PAR329 (17x36 tiles)
# PAR330 (19x19 tiles)
# PAR331 (15x29 tiles)
# PAR332 (18x28 tiles)
# PAR333 (24x35 tiles)
# PAR334 (24x25 tiles)
# PAR335 (23x33 tiles)
# PAR336 (30x35 tiles)
# PAR337 (22x29 tiles)
# PAR338 (16x24 tiles)
# PAR339 (15x23 tiles)
# PAR340 (12x24 tiles)
# PAR341 (17x15 tiles)
# PAR342 (24x39 tiles)
# PAR343 (17x28 tiles)
# PAR344 (15x30 tiles)
# PAR345 (29x26 tiles)
# PAR346 (20x37 tiles)
# PAR347 (4x7 tiles)
# PAR348 (24x27 tiles)
# PAR349 (17x26 tiles)
# PAR350 (17x36 tiles)
# PAR351 (24x32 tiles)
# PAR352 (29x22 tiles)
# PAR353 (31x36 tiles)
# PAR354 (9x14 tiles)
# PAR355 (23x34 tiles)
# PAR356 (16x18 tiles)
# PAR357 (15x19 tiles)
# PAR358 (15x28 tiles)
# PAR359 (24x18 tiles)
# PAR360 (17x23 tiles)
# PAR361 (11x5 tiles)
# PAR362 (17x17 tiles)
# PAR363 (23x25 tiles)
# PAR364 (19x13 tiles)
# PAR365 (27x16 tiles)
# PAR366 (10x15 tiles)
# PAR367 (23x14 tiles)
# PAR368 (13x25 tiles)
# PAR369 (19x25 tiles)
# PAR370 (14x35 tiles)
# PAR371 (14x23 tiles)
# PAR372 (31x16 tiles)
# PAR373 (9x11 tiles)
# PAR374 (20x21 tiles)
# PAR375 (27x15 tiles)
# PAR376 (22x38 tiles)
# PAR377 (11x28 tiles)
# PAR378 (10x29 tiles)
# PAR379 (28x34 tiles)
# PAR380 (18x23 tiles)
# PAR381 (25x28 tiles)
# PAR382 (32x41 tiles)
# PAR383 (14x28 tiles)
# PAR384 (20x26 tiles)
# PAR385 (16x29 tiles)
# PAR386 (24x41 tiles)
# PAR387 (14x12 tiles)
# PAR388 (11x17 tiles)
# PAR389 (18x32 tiles)
# PAR390 (28x40 tiles)
# PAR391 (14x34 tiles)
# PAR392 (19x29 tiles)
# PAR393 (14x36 tiles)
# PAR394 (17x14 tiles)
# PAR395 (21x38 tiles)
# PAR396 (14x22 tiles)
# PAR397 (19x17 tiles)
# PAR398 (26x22 tiles)
# PAR399 (13x25 tiles)
# PAR400 (8x19 tiles)
# PAR401 (18x26 tiles)
# PAR402 (21x23 tiles)
# PAR403 (18x22 tiles)
# PAR404 (7x26 tiles)
# PAR405 (32x16 tiles)
# PAR406 (11x22 tiles)
# PAR407 (30x19 tiles)
# PAR408 (27x27 tiles)
# PAR409 (19x23 tiles)
# PAR410 (14x22 tiles)
# PAR411 (16x23 tiles)
# PAR412 (23x32 tiles)
# PAR413 (24x36 tiles)
# PAR414 (15x24 tiles)
# PAR415 (16x34 tiles)
# PAR416 (24x14 tiles)
# PAR417 (16x23 tiles)
# PAR418 (20x21 tiles)
# PAR419 (15x30 tiles)
# PAR420 (19x21 tiles)
# PAR421 (24x18 tiles)
# PAR422 (15x22 tiles)
# PAR423 (12x27 tiles)
# PAR424 (17x31 tiles)
# PAR425 (11x29 tiles)
# PAR426 (17x25 tiles)
# PAR427 (22x16 tiles)
# PAR428 (8x23 tiles)
# PAR429 (12x21 tiles)
# PAR430 (17x24 tiles)
# PAR431 (32x34 tiles)
# PAR432 (20x24 tiles)
# PAR433 (33x37 tiles)
# PAR434 (17x15 tiles)
# PAR435 (10x22 tiles)
# Both Tile 150 rejected
#
# PAR436 (17x32 tiles)
# PAR437 (22x30 tiles)
# PAR438 (16x22 tiles)
# PAR440 (19x39 tiles)
# PAR441 (28x10 tiles)
# PAR442 (23x18 tiles)
# PAR443 (21x19 tiles)
# PAR444 (18x8 tiles)
# PAR445 (15x22 tiles)
# PAR446 (27x19 tiles)
# PAR447 (19x35 tiles)
# PAR448 (17x24 tiles)
# PAR449 (11x31 tiles)
# PAR450 (18x36 tiles)
# PAR451 (15x35 tiles)
# PAR452 (10x38 tiles)
# PAR453 (30x30 tiles)
# PAR454 (22x24 tiles)
# PAR455 (29x23 tiles)
# PAR456 (13x24 tiles)
# PAR457 (31x24 tiles)
# Both Tile 93 rejected
#
# PAR458 (24x27 tiles)
# PAR459 (15x34 tiles)
# PAR460 (8x22 tiles)
# PAR461 (25x21 tiles)
# PAR462 (19x41 tiles)
# PAR463 (22x16 tiles)
# PAR464 (17x36 tiles)
# PAR465 (22x21 tiles)
# PAR466 (17x35 tiles)
# PAR467 (15x14 tiles)
# PAR468 (27x29 tiles)
# PAR469 (18x23 tiles)
# PAR470 (7x9 tiles)
# PAR471 (15x18 tiles)
# PAR472 (21x10 tiles)
# PAR473 (16x32 tiles)
# PAR474 (14x17 tiles)
# PAR475 (15x24 tiles)
# PAR476 (19x24 tiles)
# PAR477 (26x32 tiles)
# PAR478 (20x36 tiles)
# PAR479 (26x33 tiles)
# PAR480 (25x19 tiles)
# PAR481 (12x12 tiles)
# PAR482 (8x11 tiles)
# PAR483 (29x35 tiles)
# PAR484 (21x21 tiles)
# PAR485 (21x14 tiles)
# PAR486 (20x29 tiles)
# PAR487 (18x18 tiles)
# PAR488 (6x16 tiles)
# PAR489 (19x25 tiles)
# PAR490 (10x28 tiles)
# PAR491 (18x29 tiles)
# PAR170 (22x26 tiles)
# PAR171 (24x26 tiles)
# PAR172 (16x34 tiles)
# PAR173 (14x27 tiles)
# PAR174 (10x25 tiles)
# PAR175 (19x27 tiles)
# PAR176 (24x20 tiles)
# PAR177 (22x27 tiles)
# PAR178 (8x10 tiles)
# PAR180 (21x35 tiles)
# PAR181 (17x8 tiles)
# PAR182 (17x21 tiles)
# PAR183 (18x10 tiles)
# PAR184 (12x28 tiles)
# PAR185 (18x31 tiles)
# False IM Tile 267 rejected
#
# False IM Tile 533 rejected
#
# PAR186 (22x35 tiles)
# PAR187 (22x39 tiles)
# PAR188 (15x29 tiles)
# PAR189 (14x25 tiles)
# PAR190 (16x14 tiles)
# PAR191 (25x23 tiles)
# Both Tile 41 rejected
#
# Both Tile 214 rejected
#
# Both Tile 219 rejected
#
# Both Tile 359 rejected
#
# Both Tile 370 rejected
#
# PAR192 (10x17 tiles)
# PAR194 (25x34 tiles)
# PAR197 (17x29 tiles)
# PAR198 (29x19 tiles)
# PAR199 (21x40 tiles)
# PAR200 (12x18 tiles)
# PAR201 (25x21 tiles)
# PAR202 (17x34 tiles)
# PAR203 (29x13 tiles)
# PAR204 (18x26 tiles)
# PAR205 (26x36 tiles)
# PAR206 (17x32 tiles)
# PAR207 (22x19 tiles)
# False IM Tile 187 rejected
#
# PAR208 (26x30 tiles)
# False T Tile 265 rejected
#
# PAR209 (19x23 tiles)
# False T Tile 388 rejected
#
# False T Tile 389 rejected
#
# PAR210 (18x17 tiles)
# False T Tile 23 rejected
#
# PAR211 (24x25 tiles)
# PAR212 (16x32 tiles)
# PAR213 (17x26 tiles)
# PAR214 (17x30 tiles)
# PAR215 (13x24 tiles)
# PAR216 (24x19 tiles)
# PAR217 (10x19 tiles)
# PAR218 (13x21 tiles)
# False T Tile 215 rejected
#
# PAR219 (11x24 tiles)
# False T Tile 204 rejected
#
# PAR220 (21x37 tiles)
# PAR221 (23x27 tiles)
# PAR222 (11x24 tiles)
# PAR223 (12x13 tiles)
# PAR224 (17x26 tiles)
# PAR225 (20x29 tiles)
# PAR226 (17x21 tiles)
# PAR227 (17x22 tiles)
# PAR228 (24x20 tiles)
# PAR229 (12x33 tiles)
# PAR231 (31x19 tiles)
# False IM Tile 203 rejected
#
# PAR232 (17x16 tiles)
# PAR233 (19x34 tiles)
# PAR234 (20x16 tiles)
# PAR235 (6x5 tiles)
# PAR236 (20x22 tiles)
# PAR238 (16x22 tiles)
# PAR239 (23x22 tiles)
# PAR240 (20x31 tiles)
# PAR241 (19x34 tiles)
# PAR242 (13x18 tiles)
# PAR243 (20x14 tiles)
# False T Tile 162 rejected
#
# PAR244 (13x21 tiles)
# False T Tile 97 rejected
#
# PAR245 (24x28 tiles)
# PAR246 (18x23 tiles)
# PAR247 (28x28 tiles)
# PAR248 (19x15 tiles)
# PAR249 (18x28 tiles)
# False T Tile 392 rejected
#
# PAR250 (20x29 tiles)
# PAR251 (15x27 tiles)
# PAR252 (10x15 tiles)
# PAR253 (21x21 tiles)
# PAR255 (13x28 tiles)
# PAR256 (16x26 tiles)
# PAR257 (11x30 tiles)
# PAR258 (20x28 tiles)
# PAR259 (14x18 tiles)
# PAR260 (17x22 tiles)
# PAR261 (15x30 tiles)
# PAR262 (21x30 tiles)
# PAR263 (21x32 tiles)
# PAR264 (16x28 tiles)
# PAR265 (21x26 tiles)
# PAR266 (19x19 tiles)
# PAR267 (23x38 tiles)
# PAR268 (19x34 tiles)
# PAR269 (21x34 tiles)
# PAR270 (12x31 tiles)
# PAR272 (29x31 tiles)
# PAR273 (14x25 tiles)
# PAR274 (25x36 tiles)
# PAR275 (24x19 tiles)
# PAR276 (28x25 tiles)
# PAR277 (13x21 tiles)
# PAR278 (14x26 tiles)
# PAR280 (26x28 tiles)
# PAR281 (21x13 tiles)
# PAR282 (18x18 tiles)
# PAR283 (19x28 tiles)
# PAR284 (20x32 tiles)
# PAR285 (24x17 tiles)
# PAR286 (18x23 tiles)
# PAR287 (21x14 tiles)
# PAR288 (15x32 tiles)
# PAR289 (24x28 tiles)
# PAR290 (12x16 tiles)
# PAR291 (26x26 tiles)
# False IM Tile 122 rejected
#
# PAR292 (14x25 tiles)
# PAR293 (10x27 tiles)
# PAR294 (15x20 tiles)
# PAR295 (19x10 tiles)
# PAR296 (18x27 tiles)
# PAR297 (26x23 tiles)
# PAR298 (22x18 tiles)
# PAR299 (24x36 tiles)
# PAR300 (9x6 tiles)
# PAR301 (29x24 tiles)
# PAR302 (20x31 tiles)
# PAR303 (20x23 tiles)
# PAR304 (14x32 tiles)
# PAR305 (30x34 tiles)
# PAR306 (30x28 tiles)
# False IM Tile 301 rejected
#
# False IM Tile 320 rejected
#
# False IM Tile 329 rejected
#
# False IM Tile 356 rejected
#
# False T Tile 679 rejected
#
# PAR307 (29x49 tiles)
# PAR308 (12x32 tiles)
# PAR309 (24x27 tiles)
# PAR310 (28x30 tiles)
# PAR311 (24x27 tiles)
# PAR312 (27x17 tiles)
# PAR313 (22x31 tiles)
# PAR314 (26x26 tiles)
# PAR315 (13x32 tiles)
# PAR316 (16x27 tiles)
# PAR317 (28x18 tiles)
# PAR318 (19x20 tiles)
# PAR321 (23x31 tiles)
# False IM Tile 152 rejected
#
# PAR322 (13x30 tiles)
# PAR323 (24x38 tiles)
# False IM Tile 865 rejected
#
# PAR324 (17x20 tiles)
# PAR325 (12x27 tiles)
# PAR326 (14x22 tiles)
# PAR327 (23x38 tiles)
# PAR328 (24x18 tiles)
# PAR329 (15x38 tiles)
# PAR330 (20x20 tiles)
# PAR331 (16x30 tiles)
# PAR332 (18x27 tiles)
# PAR333 (21x35 tiles)
# False IM Tile 433 rejected
#
# PAR334 (24x28 tiles)
# PAR335 (26x31 tiles)
# PAR336 (30x36 tiles)
# PAR337 (22x32 tiles)
# False T Tile 42 rejected
#
# PAR338 (17x24 tiles)
# PAR339 (16x23 tiles)
# PAR340 (13x25 tiles)
# False T Tile 235 rejected
#
# False IM Tile 305 rejected
#
# PAR341 (16x15 tiles)
# PAR342 (23x37 tiles)
# PAR343 (18x27 tiles)
# PAR344 (16x29 tiles)
# PAR345 (29x26 tiles)
# PAR347 (4x7 tiles)
# PAR348 (24x28 tiles)
# PAR349 (17x27 tiles)
# PAR350 (17x37 tiles)
# PAR351 (24x33 tiles)
# False IM Tile 53 rejected
#
# False T Tile 289 rejected
#
# PAR352 (28x23 tiles)
# PAR354 (10x15 tiles)
# PAR355 (23x34 tiles)
# PAR357 (15x17 tiles)
# PAR358 (16x28 tiles)
# PAR359 (25x17 tiles)
# PAR360 (14x23 tiles)
# PAR361 (11x6 tiles)
# PAR362 (20x17 tiles)
# False T Tile 247 rejected
#
# PAR363 (22x26 tiles)
# False T Tile 111 rejected
#
# False T Tile 197 rejected
#
# PAR364 (18x19 tiles)
# PAR365 (27x14 tiles)
# False T Tile 47 rejected
#
# PAR366 (10x15 tiles)
# PAR367 (23x17 tiles)
# PAR369 (19x24 tiles)
# PAR370 (14x35 tiles)
# PAR371 (14x23 tiles)
# PAR372 (32x18 tiles)
# PAR373 (8x11 tiles)
# PAR374 (21x20 tiles)
# PAR375 (28x14 tiles)
# PAR376 (21x37 tiles)
# False T Tile 347 rejected
#
# PAR377 (13x27 tiles)
# PAR378 (13x29 tiles)
# PAR379 (30x36 tiles)
# PAR380 (16x26 tiles)
# PAR381 (25x28 tiles)
# PAR382 (32x41 tiles)
# False T Tile 168 rejected
#
# PAR383 (15x28 tiles)
# PAR384 (20x27 tiles)
# False T Tile 403 rejected
#
# False T Tile 481 rejected
#
# PAR385 (20x26 tiles)
# PAR386 (24x42 tiles)
# PAR387 (14x11 tiles)
# PAR388 (9x18 tiles)
# PAR389 (17x34 tiles)
# PAR390 (28x42 tiles)
# PAR391 (15x34 tiles)
# PAR392 (19x29 tiles)
# PAR393 (13x36 tiles)
# False T Tile 10 rejected
#
# False T Tile 11 rejected
#
# False T Tile 41 rejected
#
# Both Tile 42 rejected
#
# False T Tile 43 rejected
#
# False T Tile 120 rejected
#
# PAR394 (17x14 tiles)
# PAR395 (20x23 tiles)
# False IM Tile 140 rejected
#
# PAR396 (14x22 tiles)
# False IM Tile 106 rejected
#
# False IM Tile 127 rejected
#
# PAR397 (19x18 tiles)
# False T Tile 205 rejected
#
# False T Tile 225 rejected
#
# PAR399 (12x27 tiles)
# PAR400 (9x19 tiles)
# PAR401 (19x25 tiles)
# PAR402 (21x23 tiles)
# PAR404 (7x26 tiles)
# PAR405 (30x16 tiles)
# PAR406 (10x22 tiles)
# PAR407 (30x19 tiles)
# PAR408 (25x24 tiles)
# False T Tile 188 rejected
#
# PAR409 (19x23 tiles)
# False IM Tile 94 rejected
#
# False IM Tile 138 rejected
#
# False IM Tile 247 rejected
#
# PAR411 (14x24 tiles)
# PAR412 (22x32 tiles)
# PAR413 (28x39 tiles)
# PAR414 (16x24 tiles)
# PAR415 (16x35 tiles)
# PAR416 (22x15 tiles)
# False IM Tile 297 rejected
#
# PAR417 (16x23 tiles)
# False IM Tile 118 rejected
#
# PAR418 (20x22 tiles)
# False T Tile 74 rejected
#
# False T Tile 96 rejected
#
# False T Tile 115 rejected
#
# False T Tile 146 rejected
#
# False T Tile 169 rejected
#
# False T Tile 213 rejected
#
# False T Tile 236 rejected
#
# False T Tile 389 rejected
#
# False T Tile 390 rejected
#
# False T Tile 392 rejected
#
# False T Tile 412 rejected
#
# False T Tile 413 rejected
#
# False T Tile 414 rejected
#
# PAR419 (16x29 tiles)
# PAR420 (19x22 tiles)
# PAR421 (22x19 tiles)
# PAR422 (13x22 tiles)
# False T Tile 102 rejected
#
# False T Tile 123 rejected
#
# False T Tile 171 rejected
#
# False T Tile 189 rejected
#
# False T Tile 190 rejected
#
# False T Tile 191 rejected
#
# False T Tile 192 rejected
#
# False T Tile 193 rejected
#
# False T Tile 203 rejected
#
# False T Tile 212 rejected
#
# False T Tile 213 rejected
#
# PAR423 (12x29 tiles)
# PAR424 (14x32 tiles)
# PAR425 (12x32 tiles)
# PAR426 (21x28 tiles)
# PAR427 (21x16 tiles)
# PAR428 (10x36 tiles)
# PAR429 (14x19 tiles)
# PAR430 (17x24 tiles)
# PAR432 (23x28 tiles)
# PAR433 (33x36 tiles)
# PAR434 (16x15 tiles)
# PAR435 (10x22 tiles)
# Both Tile 195 rejected
#
# PAR436 (23x37 tiles)
# PAR437 (23x28 tiles)
# PAR438 (16x20 tiles)
# PAR439 (16x32 tiles)
# PAR440 (22x37 tiles)
# False T Tile 699 rejected
#
# PAR441 (8x28 tiles)
# PAR442 (24x17 tiles)
# False T Tile 58 rejected
#
# False T Tile 112 rejected
#
# False T Tile 121 rejected
#
# PAR443 (21x23 tiles)
# PAR444 (18x11 tiles)
# PAR445 (16x22 tiles)
# PAR446 (27x20 tiles)
# PAR447 (21x35 tiles)
# False T Tile 306 rejected
#
# False T Tile 455 rejected
#
# False T Tile 456 rejected
#
# PAR448 (17x24 tiles)
# PAR450 (17x35 tiles)
# PAR451 (15x35 tiles)
# PAR452 (11x43 tiles)
# PAR453 (30x25 tiles)
# PAR454 (18x27 tiles)
# PAR455 (28x23 tiles)
# PAR457 (31x20 tiles)
# Both Tile 38 rejected
#
# Both Tile 80 rejected
#
# Both Tile 468 rejected
#
# Both Tile 508 rejected
#
# Both Tile 570 rejected
#
# PAR458 (23x27 tiles)
# PAR459 (13x34 tiles)
# PAR460 (8x36 tiles)
# PAR461 (25x22 tiles)
# False T Tile 318 rejected
#
# PAR462 (18x41 tiles)
# PAR463 (21x17 tiles)
# PAR464 (17x37 tiles)
# PAR465 (22x22 tiles)
# PAR466 (18x35 tiles)
# PAR467 (17x13 tiles)
# PAR468 (26x29 tiles)
# PAR469 (20x30 tiles)
# PAR470 (5x11 tiles)
# PAR471 (16x18 tiles)
# PAR472 (21x12 tiles)
# False T Tile 156 rejected
#
# False T Tile 168 rejected
#
# False T Tile 180 rejected
#
# False T Tile 192 rejected
#
# False T Tile 204 rejected
#
# PAR473 (19x24 tiles)
# PAR474 (13x17 tiles)
# PAR475 (15x24 tiles)
# PAR476 (19x25 tiles)
# PAR477 (27x31 tiles)
# PAR478 (22x35 tiles)
# PAR479 (26x33 tiles)
# PAR480 (23x20 tiles)
# PAR481 (12x13 tiles)
# False IM Tile 8 rejected
#
# PAR482 (10x10 tiles)
# PAR483 (30x41 tiles)
# False IM Tile 404 rejected
#
# PAR484 (21x21 tiles)
# PAR485 (21x15 tiles)
# PAR486 (19x29 tiles)
# PAR487 (18x25 tiles)
# PAR488 (16x48 tiles)
# PAR489 (17x28 tiles)
# PAR490 (9x27 tiles)
# PAR491 (15x30 tiles)
# False T Tile 170 rejected

# %% [markdown]
# ## Generating the immunoscore from the matrix
# Also gets the original Immonuscore
# Uses the CutOff file

# %%
# File with the cutoffs
Data_IS_original=pandas.read_csv(os.path.join('..','Immunoscore_CutOFF.csv'),sep='\t')
Cutoff_Mean_CD3CT=list(Data_IS_original['CD3CT-mean'])

Cutoff_Mean_CD3IM=list(Data_IS_original['CD3IM-mean'])

Cutoff_Mean_CD8CT=list(Data_IS_original['CD8CT-mean'])

Cutoff_Mean_CD8IM=list(Data_IS_original['CD8IM-mean'])

score_cutoff=list(Data_IS_original['score'])
print("{}\n".format(score_cutoff))

 # For each patient_id get mean of Tumor and IM per CD in csv with header
with open('../Data_output/HEGP_Immunoscore_mean.csv', 'w') as f:

    f.write('OfficialID,meanCD3_Tumor_A,meanCD3_IM_A,meanCD8_Tumor_A,meanCD8_IM_A,score_cd3ct,score_cd3im,score_cd8ct,score_cd8im,score_mean,IS_MDT\n')


    for patient_id in PATIENTS_CD3:

        try:
            cd3_data = PATIENTS_CD3[patient_id]
            cd8_data = PATIENTS_CD8[patient_id]
        except KeyError:
            continue

        # Ratio pondéré
       # mean_tumor_cd3_R = numpy.nanmean(cd3_data['Density_Tumor_images'])
       # mean_tumor_cd8_R = numpy.nanmean(cd8_data['Density_Tumor_images'])

       # mean_IM_cd3_R=numpy.nanmean(cd3_data['Density_InvasiveFront_images'])
       # mean_IM_cd8_R=numpy.nanmean(cd8_data['Density_InvasiveFront_images'])
        #amos, sum nb cell/sum surface
        mean_tumor_cd3_A=((numpy.nansum(cd3_data['Number_Cells_Tumor']))/(numpy.nansum(cd3_data['Area_Tumor_um2'])))*(1e6)

        mean_tumor_cd8_A=((numpy.nansum(cd8_data['Number_Cells_Tumor']))/(numpy.nansum(cd8_data['Area_Tumor_um2'])))*(1e6)
        mean_IM_cd3_A=((numpy.nansum(cd3_data['Number_Cells_InvasiveFront']))/(numpy.nansum(cd3_data['Area_IvasiveFront_um2'])))*(1e6)
        mean_IM_cd8_A=((numpy.nansum(cd8_data['Number_Cells_InvasiveFront']))/(numpy.nansum(cd8_data['Area_IvasiveFront_um2'])))*(1e6)

        score_cd3ct=0
        score_cd8im=0
        score_cd8ct=0
        score_cd3im=0
        score_mean=0
        for i in range(0,len(score_cutoff),1):
            if score_cd3ct==0:
                if mean_tumor_cd3_A <=Cutoff_Mean_CD3CT[i]:
                    score_cd3ct=score_cutoff[i-1]
                elif i==(len(score_cutoff)-1):
                    score_cd3ct=score_cutoff[i]
            if score_cd8ct==0:
                if mean_tumor_cd8_A <=Cutoff_Mean_CD8CT[i]:
                    score_cd8ct=score_cutoff[i-1]
                elif i==(len(score_cutoff)-1):
                    score_cd8ct=score_cutoff[i]
            if score_cd3im==0:
                if mean_IM_cd3_A <=Cutoff_Mean_CD3IM[i]:
                    score_cd3im=score_cutoff[i-1]
                elif i==(len(score_cutoff)-1):
                    score_cd3im=score_cutoff[i]
            if score_cd8im==0:
                if mean_IM_cd8_A <=Cutoff_Mean_CD8IM[i]:
                    score_cd8im=score_cutoff[i-1]
                elif i==(len(score_cutoff)-1):
                    score_cd8im=score_cutoff[i]

        score_mean=(score_cd8ct+score_cd8im+score_cd3im+score_cd3ct)/4
        #assigns Immunosore
        if score_mean<=25:
            IS_MDT=0
        elif score_mean<=70:
            IS_MDT=1
        elif score_mean>70:
            IS_MDT=2
        else:
            IS_MDT='NaN'

        f.write('{},{},{},{},{},{},{},{},{},{},{}\n'.format(patient_id, mean_tumor_cd3_A,mean_IM_cd3_A, mean_tumor_cd8_A,mean_IM_cd8_A,score_cd3ct,score_cd3im,score_cd8ct,score_cd8im,score_mean,IS_MDT))
# Out:
# [2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 77.5, 82.5, 87.5, 92.5, 97.5]
