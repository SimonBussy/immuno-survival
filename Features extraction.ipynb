# %% [markdown]
# # Features extraction

# %% [markdown]
# 1) Basis descriptors:
#
# - OpenCV http://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_feature2d/py_sift_intro/py_sift_intro.html
#
# Tu as pleins d'autres descripteurs codés ds OpenCV, je te conseil d'utiliser ça et d'en essayer plusieurs.
#
# - Tuto d'utilisation d'OpenCV pr le descripteur KAZE: https://medium.com/machine-learning-world/feature-extraction-and-similar-image-search-with-opencv-for-newbies-3c59796bf774
#
# Ce qui est intéressant dans ce tuto c'est qu'il te montre comment conserver en sortie le même nombre de features extraites, ce qui sera très utile pour nous! (out ce qui t'intéresse est extract_features(), on se fiche de Matcher().)
#
# 2) autoencoder (unsupervised deep learning) avec keras: https://blog.keras.io/building-autoencoders-in-keras.html
#
# 3) scattering transform (wavelet basis): https://github.com/edouardoyallon/pyscatwave
#
# 4) Deep survival learning (supervised donc à utiliser "à la place" du cox directement), c'est très recent et prometteur, il y a 2 implémentations:
#
# - DeepSurv:
# papier: https://arxiv.org/pdf/1606.00931.pdf
# code: https://github.com/jaredleekatzman/DeepSurv
# - SurvivalNet:
# papier (dans nature!): https://www.nature.com/articles/s41598-017-11817-6.pdf et à ICLR https://arxiv.org/pdf/1609.08663.pdf
# code: https://github.com/CancerDataScience/SurvivalNet

# %%
import cv2
import numpy
import pandas
import os
print(cv2.__version__)
#List of usable patients 
data_ID=pandas.read_csv(os.path.join('.','List_Patient_HEGP.csv'),sep=",")
# Out:
# 3.3.1

# %%
sift = cv2.xfeatures2d.SIFT_create()

# %%
print(img)

# %%
gen = numpy.array(img ,dtype=numpy.uint8)

# %%
#kp=sift.detect(img.fillna(0))

# %%
#kp=sift.detect(img.as_matrix)

# %%
#kp, des = sift.detectAndCompute(img.as_matrix,None)

# %%
alg = cv2.KAZE_create()

# %%
# Feature extractor
def extract_features(image, vector_size=32):
   
    try:
        # Using KAZE, cause SIFT, ORB and other was moved to additional module
        # which is adding addtional pain during install
        alg = cv2.KAZE_create()
        # Dinding image keypoints
        kps = alg.detect(image)
        # Getting first 32 of them. 
        # Number of keypoints is varies depend on image size and color pallet
        # Sorting them based on keypoint response value(bigger is better)
        kps = sorted(kps, key=lambda x: -x.response)[:vector_size]
        # computing descriptors vector
        kps, dsc = alg.compute(image, kps)
        # Flatten all of them in one big vector - our feature vector
        dsc = dsc.flatten()
        # Making descriptor of same size
        # Descriptor vector size is 64
        needed_size = (vector_size * 64)
        if dsc.size < needed_size:
            # if we have less the 32 descriptors then just adding zeros at the
            # end of our feature vector
            dsc = numpy.concatenate([dsc, numpy.zeros(needed_size - dsc.size)])
    except cv2.error as e:
        print ('Error:{}'.format(e))
        return None
    print('{}'.format(len(dsc)))

    return dsc

# %%
kps = extract_features(gen)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-e6e59e5fa996> in <module>()
# ----> 1 kps = extract_features(gen)
#
# <ipython-input-4-d7ebbfd6bbae> in extract_features(image, vector_size)
#      15         kps, dsc = alg.compute(image, kps)
#      16         # Flatten all of them in one big vector - our feature vector
# ---> 17         dsc = dsc.flatten()
#      18         # Making descriptor of same size
#      19         # Descriptor vector size is 64
#
# AttributeError: 'NoneType' object has no attribute 'flatten'

# %%
kps
# Out:
# array([-0.049637  ,  0.06155652,  0.05075475, ...,  0.        ,
#         0.        ,  0.        ])

# %%
len(kps)
# Out:
# 2048

# %%
size_vector_cd3=pandas.DataFrame(data=data_ID['OfficialID'],index=None)
size_vector_cd8=pandas.DataFrame(data=data_ID['OfficialID'],index=None)

# %%
for patient_id in data_ID['OfficialID']:
    CD3PATH=os.path.join('.','cache','cd3',patient_id)
    img_cd3=pandas.read_csv(os.path.join(CD3PATH,'Ratio_Cells_per_Tumor'),sep=' ',header=None)
    gen = numpy.array(img_cd3 ,dtype=numpy.uint8)
    #kps=extract_features(gen)
    extract_features(gen)
    #size_vector_cd3.loc[patient_id,'Size_Tumor']=len(kps)
    img_cd3=pandas.read_csv(os.path.join(CD3PATH,'Ratio_Cells_per_InvasiveFront'),sep=' ',header=None)
    gen = numpy.array(img_cd3 ,dtype=numpy.uint8)
    #kps=extract_features(gen)
    extract_features(gen)
    #size_vector_cd3.loc[patient_id,'Size_Density']=len(kps)
    
    CD8PATH=os.path.join('.','cache','cd8',patient_id)
    img_cd8=pandas.read_csv(os.path.join(CD8PATH,'Ratio_Cells_per_Tumor'),sep=' ',header=None)
    gen = numpy.array(img_cd8 ,dtype=numpy.uint8)
    #kps=extract_features(gen)
    extract_features(gen)
    #size_vector_cd8.loc[patient_id,'Size_Tumor']=len(kps)
    img_cd8=pandas.read_csv(os.path.join(CD8PATH,'Ratio_Cells_per_InvasiveFront'),sep=' ',header=None)
    gen = numpy.array(img_cd8 ,dtype=numpy.uint8)
    #kps=extract_features(gen)
    extract_features(gen)
    #size_vector_cd8.loc[patient_id,'Size_Density']=len(kps)
# Out:
# 2048
# 2048
# 2048
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-73b1bd5f8fc6> in <module>()
#      21     gen = numpy.array(img_cd8 ,dtype=numpy.uint8)
#      22     #kps=extract_features(gen)
# ---> 23     extract_features(gen)
#      24     #size_vector_cd8.loc[patient_id,'Size_Density']=len(kps)
#
# <ipython-input-19-579fb258cad5> in extract_features(image, vector_size)
#      15         kps, dsc = alg.compute(image, kps)
#      16         # Flatten all of them in one big vector - our feature vector
# ---> 17         dsc = dsc.flatten()
#      18         # Making descriptor of same size
#      19         # Descriptor vector size is 64
#
# AttributeError: 'NoneType' object has no attribute 'flatten'

# %%
patient_id
# Out:
# 'PAR170'

# %%
size_vector_cd3
# Out:
#        OfficialID  Size_Tumor  Size_Density
# 0          PAR170         NaN           NaN
# 1          PAR171         NaN           NaN
# 2          PAR172         NaN           NaN
# 3          PAR173         NaN           NaN
# 4          PAR174         NaN           NaN
# 5          PAR175         NaN           NaN
# 6          PAR176         NaN           NaN
# 7          PAR177         NaN           NaN
# 8          PAR178         NaN           NaN
# 9          PAR180         NaN           NaN
# 10         PAR181         NaN           NaN
# 11         PAR182         NaN           NaN
# 12         PAR183         NaN           NaN
# 13         PAR184         NaN           NaN
# 14         PAR185         NaN           NaN
# 15         PAR186         NaN           NaN
# 16         PAR187         NaN           NaN
# 17         PAR188         NaN           NaN
# 18         PAR189         NaN           NaN
# 19         PAR190         NaN           NaN
# ...
